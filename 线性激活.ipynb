# %% [markdown]
# 24.1.27

# %% [markdown]
# 线性层必须接受一维的数据，为神经元个数，所以数据必须展平后才能输入

# %%
import torch
from torch import nn
from torch.nn import Linear
import torchvision
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter


dataset = torchvision.datasets.CIFAR10('../data',train =False, transform = torchvision.transforms.ToTensor(),download = True)

# ！！！！！如果这里的drop_last不设置为true,会出现矩阵无法相乘的报错
dataloader = DataLoader(dataset,batch_size =64,drop_last=True)

class zzy(nn.Module):
    def __init__(self):
        super(zzy,self).__init__()
        self.linear1 = Linear(196608,10)

    def forward (self,input):
        output = self.linear1(input)
        return output

zzy1 =zzy()
#writer = SummaryWriter('log')
step = 0

for data in dataloader:
    imgs,targets = data
    # 此时的形状为torch.Size([64, 3, 32, 32])
    print(imgs.shape)
    # 手动展平输入图像
    # output1 = torch.reshape(imgs,(1,1,1,-1))
    # 使用torch自带的展平函数flatten
    output1 = torch.flatten(imgs)
    # 此时展平的形状为torch.Size([1, 1, 1, 196608])
    print(output1.shape)
    # 经过神经网络的线性层
    output2 = zzy1(output1)
    # 此时经过线性层的处理后，输出个数为10，torch.Size([1, 1, 1, 10])
    print(output2.shape)

    step += 1
writer.close()
# Out:
# Files already downloaded and verified
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# ...
